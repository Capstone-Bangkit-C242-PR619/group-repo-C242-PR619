# %%
import pandas as pd

# %%
df = pd.read_excel("/content/status_gizi_dataset2.xlsx")
df
# Out:
#              Nama  JK  Usia  Tgl Lahir                 Nama Ortu  \
# 0       Balita 1   P      4 2020-09-04                aji dimas
# 1        Balita 2  P      5 2019-11-18                  SARTONO
# 2        Balita 3  L      5 2019-06-20                    TOMMY
# 3        Balita 4  L      3 2021-10-08          subakti ghufron
# 4        Balita 5  P      5 2019-07-18                  ALDY P.
# ...           ...  ..   ...        ...                       ...
# 1283  Balita 1284  L      4 2020-05-28     SHERLYANA MAYANGSARI
# 1284  Balita 1285  P      4 2020-11-10                  MUSTOFA
# 1285  Balita 1286  L      4 2020-11-19                   HENDRA
# 1286  Balita 1287  L      2 2022-10-29  Muhammad Misbachul Anam
# 1287  Balita 1288  L      2 2022-08-23             LIS HIDAYATI
#
#              Desa/Kel   RT    RW  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  \
# 0            PALEBON   1.0   2.0    8.3    79.5   0.0    -1.62    -0.16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288 entries, 0 to 1287
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nama         1288 non-null   object
#  1   JK           1288 non-null   object
#  2   Usia         1288 non-null   int64
#  3   Tgl Lahir    1288 non-null   datetime64[ns]
#  4   Nama Ortu    1288 non-null   object
#  5   Desa/Kel     1285 non-null   object
#  6   RT           1264 non-null   float64
#  7   RW           1286 non-null   float64
#  8   Berat        1288 non-null   float64
#  9   Tinggi       1288 non-null   float64
#  10  LiLA         1089 non-null   float64
#  11  ZS BB/U      1288 non-null   float64
#  12  ZS TB/U      1288 non-null   float64
#  13  ZS BB/TB     1288 non-null   float64
#  14  Status Gizi  1288 non-null   object
# dtypes: datetime64[ns](1), float64(8), int64(1), object(5)
# memory usage: 151.1+ KB

# %%
df.isna().sum()
# Out:
# Nama             0
# JK               0
# Usia             0
# Tgl Lahir        0
# Nama Ortu        0
# Desa/Kel         3
# RT              24
# RW               2
# Berat            0
# Tinggi           0
# LiLA           199
# ZS BB/U          0
# ZS TB/U          0
# ZS BB/TB         0
# Status Gizi      0
# dtype: int64

# %%
print("Data duplicated : ", df.duplicated().sum())
# Out:
# Data duplicated :  0

# %%
df.describe()
# Out:
#               Usia                      Tgl Lahir           RT           RW  \
# count  1288.000000                           1288  1264.000000  1286.000000
# mean      4.323758  2020-02-08 06:19:00.372670976     3.728877     5.368585
# min       1.000000            2017-04-10 00:00:00     0.000000     0.000000
# 25%       3.000000            2019-01-22 00:00:00     2.000000     2.000000
# 50%       4.000000            2020-02-04 00:00:00     3.000000     4.000000
# 75%       5.000000            2021-02-05 12:00:00     5.000000     8.000000
# max       7.000000            2023-06-30 00:00:00    12.000000    61.000000
# std       1.333914                            NaN     2.384759     4.221982
#
#              Berat       Tinggi         LiLA      ZS BB/U      ZS TB/U  \
# count  1288.000000  1288.000000  1089.000000  1288.000000  1288.000000
# mean     10.227096    83.323292     6.124242    -1.850326    -1.892686
# ...

# %%
df.describe(include='all')
# Out:
#              Nama    JK         Usia                      Tgl Lahir Nama Ortu  \
# count        1288  1288  1288.000000                           1288      1288
# unique       1288     2          NaN                            NaN       580
# top     Balita 1     L           NaN                            NaN  ASWANDI
# freq            1   778          NaN                            NaN        14
# mean          NaN   NaN     4.323758  2020-02-08 06:19:00.372670976       NaN
# min           NaN   NaN     1.000000            2017-04-10 00:00:00       NaN
# 25%           NaN   NaN     3.000000            2019-01-22 00:00:00       NaN
# 50%           NaN   NaN     4.000000            2020-02-04 00:00:00       NaN
# 75%           NaN   NaN     5.000000            2021-02-05 12:00:00       NaN
# max           NaN   NaN     7.000000            2023-06-30 00:00:00       NaN
# std           NaN   NaN     1.333914                            NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288 entries, 0 to 1287
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nama         1288 non-null   object
#  1   JK           1288 non-null   object
#  2   Usia         1288 non-null   int64
#  3   Tgl Lahir    1288 non-null   datetime64[ns]
#  4   Nama Ortu    1288 non-null   object
#  5   Desa/Kel     1285 non-null   object
#  6   RT           1264 non-null   float64
#  7   RW           1286 non-null   float64
#  8   Berat        1288 non-null   float64
#  9   Tinggi       1288 non-null   float64
#  10  LiLA         1089 non-null   float64
#  11  ZS BB/U      1288 non-null   float64
#  12  ZS TB/U      1288 non-null   float64
#  13  ZS BB/TB     1288 non-null   float64
#  14  Status Gizi  1288 non-null   object
# dtypes: datetime64[ns](1), float64(8), int64(1), object(5)
# memory usage: 151.1+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
print("Duplicates data : ", df.duplicated().sum())
# Out:
# Duplicates data :  0

# %%
df.isna().count()
# Out:
# Nama           1288
# JK             1288
# Usia           1288
# Tgl Lahir      1288
# Nama Ortu      1288
# Desa/Kel       1288
# RT             1288
# RW             1288
# Berat          1288
# Tinggi         1288
# LiLA           1288
# ZS BB/U        1288
# ZS TB/U        1288
# ZS BB/TB       1288
# Status Gizi    1288
# dtype: int64

# %%
df = df.drop(columns=['RT'])
df
# Out:
#              Nama  JK  Usia  Tgl Lahir                 Nama Ortu  \
# 0       Balita 1   P      4 2020-09-04                aji dimas
# 1        Balita 2  P      5 2019-11-18                  SARTONO
# 2        Balita 3  L      5 2019-06-20                    TOMMY
# 3        Balita 4  L      3 2021-10-08          subakti ghufron
# 4        Balita 5  P      5 2019-07-18                  ALDY P.
# ...           ...  ..   ...        ...                       ...
# 1283  Balita 1284  L      4 2020-05-28     SHERLYANA MAYANGSARI
# 1284  Balita 1285  P      4 2020-11-10                  MUSTOFA
# 1285  Balita 1286  L      4 2020-11-19                   HENDRA
# 1286  Balita 1287  L      2 2022-10-29  Muhammad Misbachul Anam
# 1287  Balita 1288  L      2 2022-08-23             LIS HIDAYATI
#
#              Desa/Kel    RW  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  ZS BB/TB  \
# 0            PALEBON    2.0    8.3    79.5   0.0    -1.62    -0.16     -2.15
# ...

# %%
df = df.drop(columns=['RW'])
df
# Out:
#              Nama  JK  Usia  Tgl Lahir                 Nama Ortu  \
# 0       Balita 1   P      4 2020-09-04                aji dimas
# 1        Balita 2  P      5 2019-11-18                  SARTONO
# 2        Balita 3  L      5 2019-06-20                    TOMMY
# 3        Balita 4  L      3 2021-10-08          subakti ghufron
# 4        Balita 5  P      5 2019-07-18                  ALDY P.
# ...           ...  ..   ...        ...                       ...
# 1283  Balita 1284  L      4 2020-05-28     SHERLYANA MAYANGSARI
# 1284  Balita 1285  P      4 2020-11-10                  MUSTOFA
# 1285  Balita 1286  L      4 2020-11-19                   HENDRA
# 1286  Balita 1287  L      2 2022-10-29  Muhammad Misbachul Anam
# 1287  Balita 1288  L      2 2022-08-23             LIS HIDAYATI
#
#              Desa/Kel  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  ZS BB/TB  \
# 0            PALEBON     8.3    79.5   0.0    -1.62    -0.16     -2.15
# ...

# %%
df = df.drop(columns=['Nama Ortu'])
df
# Out:
#              Nama  JK  Usia  Tgl Lahir         Desa/Kel  Berat  Tinggi  LiLA  \
# 0       Balita 1   P      4 2020-09-04         PALEBON     8.3    79.5   0.0
# 1        Balita 2  P      5 2019-11-18         PALEBON     9.7    85.6   0.0
# 2        Balita 3  L      5 2019-06-20         PALEBON    11.0    92.5  14.4
# 3        Balita 4  L      3 2021-10-08         PALEBON     5.7    57.0   NaN
# 4        Balita 5  P      5 2019-07-18         PALEBON     8.6    78.4  13.5
# ...           ...  ..   ...        ...              ...    ...     ...   ...
# 1283  Balita 1284  L      4 2020-05-28  PLAMONGAN SARI    10.8    88.5   NaN
# 1284  Balita 1285  P      4 2020-11-10  PLAMONGAN SARI    10.1    84.2   0.0
# 1285  Balita 1286  L      4 2020-11-19  PLAMONGAN SARI     9.3    83.5   0.0
# 1286  Balita 1287  L      2 2022-10-29  PLAMONGAN SARI     8.5    65.0   NaN
# 1287  Balita 1288  L      2 2022-08-23  PLAMONGAN SARI     7.9    68.0   0.0
#
# ...

# %%
df = df.drop(columns=['Desa/Kel'])
df
# Out:
#              Nama  JK  Usia  Tgl Lahir  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  \
# 0       Balita 1   P      4 2020-09-04    8.3    79.5   0.0    -1.62    -0.16
# 1        Balita 2  P      5 2019-11-18    9.7    85.6   0.0    -1.83    -0.78
# 2        Balita 3  L      5 2019-06-20   11.0    92.5  14.4    -1.81    -0.21
# 3        Balita 4  L      3 2021-10-08    5.7    57.0   NaN    -0.94    -2.15
# 4        Balita 5  P      5 2019-07-18    8.6    78.4  13.5    -3.26    -3.67
# ...           ...  ..   ...        ...    ...     ...   ...      ...      ...
# 1283  Balita 1284  L      4 2020-05-28   10.8    88.5   NaN    -2.40    -2.11
# 1284  Balita 1285  P      4 2020-11-10   10.1    84.2   0.0    -2.01    -2.01
# 1285  Balita 1286  L      4 2020-11-19    9.3    83.5   0.0    -3.12    -2.59
# 1286  Balita 1287  L      2 2022-10-29    8.5    65.0   NaN     0.14    -2.06
# 1287  Balita 1288  L      2 2022-08-23    7.9    68.0   0.0    -1.21    -2.01
#
# ...

# %%
df = df.drop(columns=['Tgl Lahir'])
df
# Out:
#              Nama  JK  Usia  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  ZS BB/TB  \
# 0       Balita 1   P      4    8.3    79.5   0.0    -1.62    -0.16     -2.15
# 1        Balita 2  P      5    9.7    85.6   0.0    -1.83    -0.78     -2.02
# 2        Balita 3  L      5   11.0    92.5  14.4    -1.81    -0.21     -2.62
# 3        Balita 4  L      3    5.7    57.0   NaN    -0.94    -2.15      1.23
# 4        Balita 5  P      5    8.6    78.4  13.5    -3.26    -3.67     -1.47
# ...           ...  ..   ...    ...     ...   ...      ...      ...       ...
# 1283  Balita 1284  L      4   10.8    88.5   NaN    -2.40    -2.11     -1.89
# 1284  Balita 1285  P      4   10.1    84.2   0.0    -2.01    -2.01     -1.18
# 1285  Balita 1286  L      4    9.3    83.5   0.0    -3.12    -2.59     -2.47
# 1286  Balita 1287  L      2    8.5    65.0   NaN     0.14    -2.06      1.85
# 1287  Balita 1288  L      2    7.9    68.0   0.0    -1.21    -2.01     -0.10
#
#             Status Gizi
# ...

# %%
df = df.dropna()
df
# Out:
#              Nama  JK  Usia  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  ZS BB/TB  \
# 0       Balita 1   P      4    8.3    79.5   0.0    -1.62    -0.16     -2.15
# 1        Balita 2  P      5    9.7    85.6   0.0    -1.83    -0.78     -2.02
# 2        Balita 3  L      5   11.0    92.5  14.4    -1.81    -0.21     -2.62
# 4        Balita 5  P      5    8.6    78.4  13.5    -3.26    -3.67     -1.47
# 5        Balita 6  L      4    8.9    78.0  14.0    -2.20    -2.02     -1.69
# ...           ...  ..   ...    ...     ...   ...      ...      ...       ...
# 1281  Balita 1282  P      4   10.2    82.0   0.0    -2.60    -3.58     -0.51
# 1282  Balita 1283  L      4   10.7    88.6   0.0    -2.50    -2.12     -2.04
# 1284  Balita 1285  P      4   10.1    84.2   0.0    -2.01    -2.01     -1.18
# 1285  Balita 1286  L      4    9.3    83.5   0.0    -3.12    -2.59     -2.47
# 1287  Balita 1288  L      2    7.9    68.0   0.0    -1.21    -2.01     -0.10
#
#       Status Gizi
# 0     Gizi Kurang
# ...

# %%
df['Nama'] = df['Nama'].str.lower()
df
# Out:
# <ipython-input-20-63fc45f056c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nama'] = df['Nama'].str.lower()
#              Nama  JK  Usia  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  ZS BB/TB  \
# 0       balita 1   P      4    8.3    79.5   0.0    -1.62    -0.16     -2.15
# 1        balita 2  P      5    9.7    85.6   0.0    -1.83    -0.78     -2.02
# 2        balita 3  L      5   11.0    92.5  14.4    -1.81    -0.21     -2.62
# 4        balita 5  P      5    8.6    78.4  13.5    -3.26    -3.67     -1.47
# 5        balita 6  L      4    8.9    78.0  14.0    -2.20    -2.02     -1.69
# ...           ...  ..   ...    ...     ...   ...      ...      ...       ...
# ...

# %%
df['Status Gizi'] = df['Status Gizi'].str.lower()
df
# Out:
# <ipython-input-21-000c5545385a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Status Gizi'] = df['Status Gizi'].str.lower()
#              Nama  JK  Usia  Berat  Tinggi  LiLA  ZS BB/U  ZS TB/U  ZS BB/TB  \
# 0       balita 1   P      4    8.3    79.5   0.0    -1.62    -0.16     -2.15
# 1        balita 2  P      5    9.7    85.6   0.0    -1.83    -0.78     -2.02
# 2        balita 3  L      5   11.0    92.5  14.4    -1.81    -0.21     -2.62
# 4        balita 5  P      5    8.6    78.4  13.5    -3.26    -3.67     -1.47
# 5        balita 6  L      4    8.9    78.0  14.0    -2.20    -2.02     -1.69
# ...           ...  ..   ...    ...     ...   ...      ...      ...       ...
# ...

# %%
df.to_csv("status_gizi_clean2.csv")
